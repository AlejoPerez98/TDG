# %% [markdown]
# # **1. Contexto del Análisis**
#
# En el ámbito del comercio exterior, los microdatos de exportaciones son esenciales para el análisis de las dinámicas comerciales que impactan tanto a nivel microeconómico, en términos de empresas, como a nivel macroeconómico, en cuanto a la economía nacional. La exportación, entendida como la salida de mercancías del territorio aduanero colombiano hacia otros países, zonas francas o depósitos francos, está regida por un conjunto normativo que asegura el cumplimiento de las disposiciones aduaneras, con el fin de garantizar un comercio exterior controlado y transparente.

# %% [markdown]
# ### Importar librerías

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# Mostrar todos los datos del dataframe
pd.options.display.max_columns = None # Muestra todas las columnas
pd.set_option('display.max_rows', None) # Muestra todas las filas

# %% [markdown]
# #### Carga y visualización del archivo de ejemplo

# %%
# Ruta y carga del archivo
df = pd.read_excel('C:/Users/Aleja/OneDrive/Escritorio/Icesi/TDG/TDG/Data/01_Exportaciones_2025_Enero.xlsx')

# Mostrar las primeras filas del DataFrame
print(df.head(5))
# Out:
#    FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 0         202501             1       99                    3
# 1         202501             1       99                   87
# 2         202501             2       99                   87
# 3         202501             1       99                   87
# 4         202501             3       99                   87
#
#                              ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  \
# 0  Aduanas de Bogotá -  Aeropuerto El Dorado           2     900647398.0
# 1                    Aduanas de Barranquilla           2     860026753.0
# 2                    Aduanas de Barranquilla           2     802009120.0
# 3                    Aduanas de Barranquilla           2     802009120.0
# 4                    Aduanas de Barranquilla           2     802009120.0
#
#    TIPO_USUARIO  COD_USUARIO  CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  \
# 0            36            0                 2                76001
# 1            36            0                 2                11001
# 2            36            0                 2                11001
# 3            36            0                 2                11001
# 4            36            0                 2                11001
#
#    COD_PAIS_DESTINO_NUM COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO  \
# 0                   344                  HKG              HKG
# 1                    52                  BRB              BRB
# 2                   840                  USA              USA
# 3                   840                  USA              USA
# 4                   840                  USA              USA
#
#                                   PAIS_DESTINO_FINAL CIUDAD_DESTINATARIO  \
# 0  China, región administrativa especial de Hong ...             KOWLOON
# 1                                           Barbados       CHRIST CHURCH
# 2                          Estados Unidos de América       SAN FRANCISCO
# 3                          Estados Unidos de América       SAN FRANCISCO
# 4                          Estados Unidos de América          GREENFIELD
#
#    NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION TIPO_DESPACHO  \
# 0                 6.027742e+12                 1       Inicial
# 1                 6.027740e+12                 1       Inicial
# 2                 6.027741e+12                 1       Inicial
# 3                 6.027741e+12                 1       Inicial
# 4                 6.027741e+12                 1       Inicial
#
#    COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  COD_REGION_PROCEDENCIA  \
# 0                     3                BOG                      11
# 1                    87                BAQ                       8
# 2                    87                BAQ                      11
# 3                    87                BAQ                      11
# 4                    87                BAQ                      11
#
#   REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  FECH_DECLA_EXPORTACION_ANT  \
# 0          BOGOTA DC                           0                           0
# 1          ATLANTICO               6007746609258                      202412
# 2          BOGOTA DC                           0                           0
# 3          BOGOTA DC                           0                           0
# 4          BOGOTA DC                           0                           0
#
#    NUM_DECLARACION_PRECEDENTE  FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE  \
# 0                           0                      0                      NaN
# 1                           0                      0                      NaN
# 2                           0                      0                      NaN
# 3                           0                      0                      NaN
# 4                           0                      0                      NaN
#
#   COD_MONEDA_TRANSACCION  COD_MODO_TRANSPORTE MODO_TRANSPORTE  BANDERA  \
# 0                    USD                    4           Aéreo        8
# 1                    USD                    1        Marítimo       28
# 2                    USD                    1        Marítimo       28
# 3                    USD                    1        Marítimo       28
# 4                    USD                    1        Marítimo       28
#
#   COD_NACIONALIDAD_BANDERA NACIONALIDAD_BANDERA  COD_REGIMEN_CAN  \
# 0                      ALB              Albania                1
# 1                      ATG    Antigua y Barbuda                1
# 2                      ATG    Antigua y Barbuda                1
# 3                      ATG    Antigua y Barbuda                1
# 4                      ATG    Antigua y Barbuda                1
#
#    COD_MODALIDAD_EXPORTACION  \
# 0                        199
# 1                        199
# 2                        198
# 3                        198
# 4                        198
#
#                                MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 0  Las demás exportaciones definitivas no incluid...           1
# 1  Las demás exportaciones definitivas no incluid...           1
# 2  Exportación definitiva de mercancías de fabric...           1
# 3  Exportación definitiva de mercancías de fabric...           1
# 4  Exportación definitiva de mercancías de fabric...           1
#
#    COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 0                  1            Unico               1
# 1                  1            Unico               2
# 2                  1            Unico               1
# 3                  1            Unico               1
# 4                  1            Unico               1
#
#                       TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN  \
# 0           Definitivos al embarque                        8
# 1  Definitivos despúes del embarque                        8
# 2           Definitivos al embarque                        8
# 3           Definitivos al embarque                        8
# 4           Definitivos al embarque                        8
#
#   SISTEMAS_ESPECIALES COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  \
# 0                  NO                        N                      NO
# 1                  NO                        N                      NO
# 2                  SI                        N                      NO
# 3                  SI                        N                      NO
# 4                  SI                        N                      NO
#
#    SUBPARTIDA  COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 0  7103912000                 15           BOYACA                     53
# 1  7210610000                  8        ATLANTICO                     33
# 2  1704909000                 11        BOGOTA DC                     33
# 3  1704909000                 11        BOGOTA DC                     33
# 4  1704909000                 11        BOGOTA DC                     33
#
#   COD_UNIDAD_FISICA_ALF UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 0                   C/T       Quilate                     145.55
# 1                    KG     Kilogramo                   42734.00
# 2                    KG     Kilogramo                    1462.16
# 3                    KG     Kilogramo                    5036.42
# 4                    KG     Kilogramo                     703.68
#
#    PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 0            0.03           0.02      108800.00     4.619267e+08
# 1        43119.00       42734.00       44379.79     1.917735e+08
# 2         1481.43        1462.16       13810.94     6.015369e+07
# 3         5102.82        5036.42       91276.42     3.975554e+08
# 4          739.88         703.68       13422.12     5.846018e+07
#
#    VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 0                        0.00                     0.0
# 1                        0.00                  6260.0
# 2                     3722.40                     0.0
# 3                    23040.99                     0.0
# 4                    10843.57                     0.0
#
#    VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 0                      0.0                         0.0                  3
# 1                      0.0                         0.0                 87
# 2                      0.0                         0.0                 87
# 3                      0.0                         0.0                 87
# 4                      0.0                         0.0                 87
#
#                                ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  \
# 0  Aduanas de Bogotá -  Aeropuerto El Dorado                         202501
# 1                    Aduanas de Barranquilla                         202412
# 2                    Aduanas de Barranquilla                         202501
# 3                    Aduanas de Barranquilla                         202501
# 4                    Aduanas de Barranquilla                         202501
#
#    NUMERO_FORMULARIO  FECHA_DECLARACION_EXPORTACION  \
# 0      6007749406121                       20250124
# 1      6007748464329                       20250110
# 2      6007748424700                       20250107
# 3      6007748424700                       20250107
# 4      6007748424718                       20250107
#
#        RAZON_SOCIAL_EXPORTADOR                      DIREC_EXPORTADOR  \
# 0  THE PREMIER TRADING CI  SAS     CL 20 NORTE   5 B N   38 OF   301
# 1       ACESCO COLOMBIA S.A.S.  AV CL 116   7   15 IN 2 P 17 OF 1701
# 2            C.I. PROCAPS S.A.                   CL 25 G   100    24
# 3            C.I. PROCAPS S.A.                   CL 25 G   100    24
# 4            C.I. PROCAPS S.A.                   CL 25 G   100    24
#
#    NIT_DECLARANTE                            RAZON_SOCIAL_DECLARANTE  \
# 0     890309238.0            AGENCIA DE ADUANAS FEDEGAL SAS NIVEL II
# 1     860026753.0                             ACESCO COLOMBIA S.A.S.
# 2     830003079.0  AGENCIA DE ADUANAS PROFESIONAL S.A.S NIVEL 1 -...
# 3     830003079.0  AGENCIA DE ADUANAS PROFESIONAL S.A.S NIVEL 1 -...
# 4     830003079.0  AGENCIA DE ADUANAS PROFESIONAL S.A.S NIVEL 1 -...
#
#   RAZON_SOCIAL_DESTINATARIO                             DOMICILIO_DESTINATARIO
# 0           VR TRADING LTD.  ROOM 1402, HIP KWAN COMMERCIAL BLDG, NO. 38 PI...
# 1  BARBADOS STEEL WORKS LTD                    NEWTON INDUSTRIAL PARK-BARBADOS
# 2                  OLLY PBC  415 Jackson Street Second FloorSan Francisco C...
# 3                  OLLY PBC  415 Jackson Street Second FloorSan Francisco C...
# 4      WINGED NUTRITION LLC                4268 WEST 300 N GREENFIELD IN 46140

# %%
# Mostrar las últimas filas filas del DataFrame
print(df.tail(5))
# Out:
#        FECHA_PROCESO  NUMERO_SERIE  OFICINA  COD_ADUANA_DESPACHO  \
# 96002         202501             1       99                   89
# 96003         202501             1       99                   89
# 96004         202501             1       99                   89
# 96005         202501             6       99                   89
# 96006         202501             5       99                   89
#
#          ADUANA_DESPACHO  TIPO_IDENT  NIT_EXPORTADOR  TIPO_USUARIO  \
# 96002  Aduanas de Cúcuta           2     900711875.0            36
# 96003  Aduanas de Cúcuta           2     800218958.0            36
# 96004  Aduanas de Cúcuta           2     800245795.0            36
# 96005  Aduanas de Cúcuta           2     811036030.0            36
# 96006  Aduanas de Cúcuta           2     811036030.0            36
#
#        COD_USUARIO  CLASE_EXPORTADOR  COD_DPTO_EXPORTADOR  \
# 96002            0                 2                54001
# 96003            0                 2                13001
# 96004            0                 2                11001
# 96005            0                 2                 8001
# 96006            0                 2                 8001
#
#        COD_PAIS_DESTINO_NUM COD_PAIS_DESTINO_ALF COD_PAIS_DESTINO  \
# 96002                   862                  VEN              VEN
# 96003                   862                  VEN              VEN
# 96004                   862                  VEN              VEN
# 96005                   862                  VEN              VEN
# 96006                   862                  VEN              VEN
#
#                          PAIS_DESTINO_FINAL CIUDAD_DESTINATARIO  \
# 96002  Venezuela (República Bolivariana de)            VALENCIA
# 96003  Venezuela (República Bolivariana de)       SANTA BARBARA
# 96004  Venezuela (República Bolivariana de)             CARACAS
# 96005  Venezuela (República Bolivariana de)        BARQUISIMETO
# 96006  Venezuela (República Bolivariana de)        BARQUISIMETO
#
#        NUM_SOLICITUD_AUTO_EMBARQUE  TIPO_DECLARACION TIPO_DESPACHO  \
# 96002                 6.027743e+12                 1       Inicial
# 96003                 6.027741e+12                 1       Inicial
# 96004                 6.027742e+12                 1       Inicial
# 96005                 6.027742e+12                 1       Inicial
# 96006                 6.027742e+12                 1       Inicial
#
#        COD_LUGAR_SALIDA_NUM COD_LUG_SALIDA_ALF  COD_REGION_PROCEDENCIA  \
# 96002                    89                CUC                       5
# 96003                    89                CUC                      11
# 96004                    89                CUC                       5
# 96005                    89                CUC                       5
# 96006                    89                CUC                       5
#
#       REGION_PROCEDENCIA  NUM__DECLA_EXPORTACION_ANT  \
# 96002          ANTIOQUIA                           0
# 96003          BOGOTA DC                           0
# 96004          ANTIOQUIA                           0
# 96005          ANTIOQUIA                           0
# 96006          ANTIOQUIA                           0
#
#        FECH_DECLA_EXPORTACION_ANT  NUM_DECLARACION_PRECEDENTE  \
# 96002                           0                           0
# 96003                           0                           0
# 96004                           0                           0
# 96005                           0                           0
# 96006                           0                           0
#
#        FECH_DECLA_PRECEDENTE COD_MODALIDAD_PRECEDENTE COD_MONEDA_TRANSACCION  \
# 96002                      0                      NaN                    USD
# 96003                      0                      NaN                    USD
# 96004                      0                      NaN                    USD
# 96005                      0                      NaN                    USD
# 96006                      0                      NaN                    USD
#
#        COD_MODO_TRANSPORTE        MODO_TRANSPORTE  BANDERA  \
# 96002                    3  Terrestre (carretero)      862
# 96003                    3  Terrestre (carretero)      862
# 96004                    3  Terrestre (carretero)      862
# 96005                    3  Terrestre (carretero)      862
# 96006                    3  Terrestre (carretero)      862
#
#       COD_NACIONALIDAD_BANDERA                  NACIONALIDAD_BANDERA  \
# 96002                      VEN  Venezuela (República Bolivariana de)
# 96003                      VEN  Venezuela (República Bolivariana de)
# 96004                      VEN  Venezuela (República Bolivariana de)
# 96005                      VEN  Venezuela (República Bolivariana de)
# 96006                      VEN  Venezuela (República Bolivariana de)
#
#        COD_REGIMEN_CAN  COD_MODALIDAD_EXPORTACION  \
# 96002                1                        198
# 96003                1                        198
# 96004                1                        198
# 96005                1                        107
# 96006                1                        107
#
#                                    MODALIDAD_EXPORTACION  FORMA_PAGO  \
# 96002  Exportación definitiva de mercancías de fabric...           1
# 96003  Exportación definitiva de mercancías de fabric...           1
# 96004  Exportación definitiva de mercancías de fabric...           1
# 96005                                         Donaciones           2
# 96006                                         Donaciones           2
#
#        COD_TIPO_EMBARQUE TIPO_DE_EMBARQUE  COD_TIPO_DATOS  \
# 96002                  1            Unico               1
# 96003                  1            Unico               1
# 96004                  1            Unico               1
# 96005                  1            Unico               1
# 96006                  1            Unico               1
#
#                  TIPO_DE_DATOS  TIPO_CERTIFICADO_ORIGEN SISTEMAS_ESPECIALES  \
# 96002  Definitivos al embarque                        8                  NO
# 96003  Definitivos al embarque                        8                  NO
# 96004  Definitivos al embarque                        8                  NO
# 96005  Definitivos al embarque                        8                  NO
# 96006  Definitivos al embarque                        8                  NO
#
#       COD_EXPORTACION_TRANSITO EXPORTACION_EN_TRANSITO  SUBPARTIDA  \
# 96002                        N                      NO  7310299000
# 96003                        N                      NO  3920100000
# 96004                        N                      NO   402211900
# 96005                        N                      NO  3923309900
# 96006                        N                      NO  4911100000
#
#        COD_REGION_ORIGEN REGION_DE_ORIGEN  COD_UNIDAD_FISICA_NUM  \
# 96002                  5        ANTIOQUIA                     11
# 96003                 11        BOGOTA DC                     33
# 96004                  5        ANTIOQUIA                     33
# 96005                  5        ANTIOQUIA                     11
# 96006                  5        ANTIOQUIA                     33
#
#       COD_UNIDAD_FISICA_ALF         UNIDAD_FISICA  CANTIDAD_UNIDADES_FISICAS  \
# 96002                     U  Unidades o artículos                    27500.0
# 96003                    KG             Kilogramo                     6909.3
# 96004                    KG             Kilogramo                    27000.0
# 96005                     U  Unidades o artículos                      375.0
# 96006                    KG             Kilogramo                        5.0
#
#        PESO_BRUTO_KGS  PESO_NETO_KGS  VALOR_FOB_USD  VALOR_FOB_PESOS  \
# 96002         5637.50         5417.5       23364.34     9.861761e+07
# 96003         7401.87         6909.3       51517.43     2.237649e+08
# 96004        28300.00        27000.0      123390.00     5.360395e+08
# 96005           58.29           57.0           7.50     3.258202e+04
# 96006            5.11            5.0           6.00     2.606562e+04
#
#        VLR_SERIE_AGREGADO_NAL_USD  VALOR_SERIE_FLETES_USD  \
# 96002                         0.0                     0.0
# 96003                         0.0                     0.0
# 96004                         0.0                     0.0
# 96005                         0.0                     0.0
# 96006                         0.0                     0.0
#
#        VALOR_SERIE_SEGUROS_USD  VLR_SERIE_OTROS_GASTOS_USD  COD_ADUANA_SALIDA  \
# 96002                      0.0                        0.00                 89
# 96003                      0.0                      684.37                 89
# 96004                      0.0                        0.00                 89
# 96005                      0.0                        0.00                 89
# 96006                      0.0                        0.00                 89
#
#            ADUANA_SALIDA  FECHA_SOLICITUD_AUTO_EMBARQUE  NUMERO_FORMULARIO  \
# 96002  Aduanas de Cúcuta                         202501      6007749470487
# 96003  Aduanas de Cúcuta                         202412      6007747662802
# 96004  Aduanas de Cúcuta                         202501      6007748616288
# 96005  Aduanas de Cúcuta                         202501      6007749049802
# 96006  Aduanas de Cúcuta                         202501      6007749049802
#
#        FECHA_DECLARACION_EXPORTACION  \
# 96002                       20250128
# 96003                       20250113
# 96004                       20250121
# 96005                       20250118
# 96006                       20250118
#
#                              RAZON_SOCIAL_EXPORTADOR  \
# 96002  COMERCIALIZADORA INTERNACIONAL RUBICAM S.A.S.
# 96003                             FLEXO SPRING S A S
# 96004                        LACTALIS COLOMBIA S.A.S
# 96005       COMPAÑIA NACIONAL DE CHOCOLATES S. A. S.
# 96006       COMPAÑIA NACIONAL DE CHOCOLATES S. A. S.
#
#                                         DIREC_EXPORTADOR  NIT_DECLARANTE  \
# 96002  AV 7   21 N   55 OF 311 ED CC EMPRESARIAL ESTA...     804015975.0
# 96003  BRR BRUSELAS CL SIMON BOSSA TV 37   24   33  E...     802013889.0
# 96004                              AC 24   95   12 BG 16     860066749.0
# 96005  CR 53   106   280 OF 8 A P 8 TO B  CENTRO EMPR...     800227414.0
# 96006  CR 53   106   280 OF 8 A P 8 TO B  CENTRO EMPR...     800227414.0
#
#                                  RAZON_SOCIAL_DECLARANTE  \
# 96002            AGENCIA DE ADUANAS ARNEL S.A.S. NIVEL 2
# 96003              AGENCIA DE ADUANAS FESIA S.A. NIVEL 2
# 96004  AGENCIA  DE  ADUANAS   ADUANAMIENTOS  LTDA  NI...
# 96005             AGENCIA DE ADUANAS MERCO S.A.S NIVEL 1
# 96006             AGENCIA DE ADUANAS MERCO S.A.S NIVEL 1
#
#               RAZON_SOCIAL_DESTINATARIO  \
# 96002                   COVEUS GROUP CA
# 96003      GENERAL DE ALIMENTOS NISA CA
# 96004  INDUSTRIA LACTEA VENEZOLANA. C.A
# 96005               SUPER DULCE BD C.A.
# 96006               SUPER DULCE BD C.A.
#
#                                   DOMICILIO_DESTINATARIO
# 96002                 AV HENRRY FORD LOCAL GALPON NRO 03
# 96003  CARRETERA VIA AEROP. KM. 1 EDIFICIO COLONA STA...
# 96004                CLL SAN FRANCISCO CON CLL PALMARITO
# 96005  CCR. 7 PARCELA 197 Y 198 LOCAL NR. S/N ZONA IN...
# 96006  CCR. 7 PARCELA 197 Y 198 LOCAL NR. S/N ZONA IN...

# %%
# Visualizar el tamaño del dataframe
df.shape
# Out:
# (96007, 72)

# %%
# Visualizar estructura del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96007 entries, 0 to 96006
# Data columns (total 72 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FECHA_PROCESO                  96007 non-null  int64
#  1   NUMERO_SERIE                   96007 non-null  int64
#  2   OFICINA                        96007 non-null  int64
#  3   COD_ADUANA_DESPACHO            96007 non-null  int64
#  4   ADUANA_DESPACHO                96007 non-null  object
#  5   TIPO_IDENT                     96007 non-null  int64
#  6   NIT_EXPORTADOR                 95509 non-null  float64
#  7   TIPO_USUARIO                   96007 non-null  int64
#  8   COD_USUARIO                    96007 non-null  int64
#  9   CLASE_EXPORTADOR               96007 non-null  int64
#  10  COD_DPTO_EXPORTADOR            96007 non-null  int64
#  11  COD_PAIS_DESTINO_NUM           96007 non-null  int64
#  12  COD_PAIS_DESTINO_ALF           96007 non-null  object
#  13  COD_PAIS_DESTINO               96007 non-null  object
#  14  PAIS_DESTINO_FINAL             96007 non-null  object
#  15  CIUDAD_DESTINATARIO            95965 non-null  object
#  16  NUM_SOLICITUD_AUTO_EMBARQUE    95965 non-null  float64
#  17  TIPO_DECLARACION               96007 non-null  int64
#  18  TIPO_DESPACHO                  96007 non-null  object
#  19  COD_LUGAR_SALIDA_NUM           96007 non-null  int64
#  20  COD_LUG_SALIDA_ALF             96007 non-null  object
#  21  COD_REGION_PROCEDENCIA         96007 non-null  int64
#  22  REGION_PROCEDENCIA             96007 non-null  object
#  23  NUM__DECLA_EXPORTACION_ANT     96007 non-null  int64
#  24  FECH_DECLA_EXPORTACION_ANT     96007 non-null  int64
#  25  NUM_DECLARACION_PRECEDENTE     96007 non-null  int64
#  26  FECH_DECLA_PRECEDENTE          96007 non-null  int64
#  27  COD_MODALIDAD_PRECEDENTE       2524 non-null   object
#  28  COD_MONEDA_TRANSACCION         96007 non-null  object
#  29  COD_MODO_TRANSPORTE            96007 non-null  int64
#  30  MODO_TRANSPORTE                96007 non-null  object
#  31  BANDERA                        96007 non-null  int64
#  32  COD_NACIONALIDAD_BANDERA       96007 non-null  object
#  33  NACIONALIDAD_BANDERA           96007 non-null  object
#  34  COD_REGIMEN_CAN                96007 non-null  int64
#  35  COD_MODALIDAD_EXPORTACION      96007 non-null  int64
#  36  MODALIDAD_EXPORTACION          96007 non-null  object
#  37  FORMA_PAGO                     96007 non-null  int64
#  38  COD_TIPO_EMBARQUE              96007 non-null  int64
#  39  TIPO_DE_EMBARQUE               96007 non-null  object
#  40  COD_TIPO_DATOS                 96007 non-null  int64
#  41  TIPO_DE_DATOS                  96007 non-null  object
#  42  TIPO_CERTIFICADO_ORIGEN        96007 non-null  int64
#  43  SISTEMAS_ESPECIALES            96007 non-null  object
#  44  COD_EXPORTACION_TRANSITO       96007 non-null  object
#  45  EXPORTACION_EN_TRANSITO        96007 non-null  object
#  46  SUBPARTIDA                     96007 non-null  int64
#  47  COD_REGION_ORIGEN              96007 non-null  int64
#  48  REGION_DE_ORIGEN               96007 non-null  object
#  49  COD_UNIDAD_FISICA_NUM          96007 non-null  int64
#  50  COD_UNIDAD_FISICA_ALF          96007 non-null  object
#  51  UNIDAD_FISICA                  96007 non-null  object
#  52  CANTIDAD_UNIDADES_FISICAS      96007 non-null  float64
#  53  PESO_BRUTO_KGS                 96007 non-null  float64
#  54  PESO_NETO_KGS                  96007 non-null  float64
#  55  VALOR_FOB_USD                  96007 non-null  float64
#  56  VALOR_FOB_PESOS                96007 non-null  float64
#  57  VLR_SERIE_AGREGADO_NAL_USD     96007 non-null  float64
#  58  VALOR_SERIE_FLETES_USD         96007 non-null  float64
#  59  VALOR_SERIE_SEGUROS_USD        96007 non-null  float64
#  60  VLR_SERIE_OTROS_GASTOS_USD     96007 non-null  float64
#  61  COD_ADUANA_SALIDA              96007 non-null  int64
#  62  ADUANA_SALIDA                  96007 non-null  object
#  63  FECHA_SOLICITUD_AUTO_EMBARQUE  96007 non-null  int64
#  64  NUMERO_FORMULARIO              96007 non-null  int64
#  65  FECHA_DECLARACION_EXPORTACION  96007 non-null  int64
#  66  RAZON_SOCIAL_EXPORTADOR        96007 non-null  object
#  67  DIREC_EXPORTADOR               95509 non-null  object
#  68  NIT_DECLARANTE                 95861 non-null  float64
#  69  RAZON_SOCIAL_DECLARANTE        96007 non-null  object
#  70  RAZON_SOCIAL_DESTINATARIO      96007 non-null  object
#  71  DOMICILIO_DESTINATARIO         95997 non-null  object
# dtypes: float64(12), int64(32), object(28)
# memory usage: 52.7+ MB

# %%
# Primero, convertimos las columnas que contienen "FECHA" a datetime
for col in df.columns:
    if 'FECHA' in col.upper():
        df[col] = pd.to_datetime(df[col], errors='coerce', format='%Y%m%d')

# Luego, convertimos el resto de columnas al tipo más apropiado
df = df.astype({
    'NUMERO_SERIE': 'Int64',
    'OFICINA': 'Int64',
    'COD_ADUANA_DESPACHO': 'Int64',
    'ADUANA_DESPACHO': 'string',
    'TIPO_IDENT': 'Int64',
    'NIT_EXPORTADOR': 'Float64',
    'TIPO_USUARIO': 'Int64',
    'COD_USUARIO': 'Int64',
    'CLASE_EXPORTADOR': 'Int64',
    'COD_DPTO_EXPORTADOR': 'Int64',
    'COD_PAIS_DESTINO_NUM': 'Int64',
    'COD_PAIS_DESTINO_ALF': 'string',
    'COD_PAIS_DESTINO': 'string',
    'PAIS_DESTINO_FINAL': 'string',
    'CIUDAD_DESTINATARIO': 'string',
    'NUM_SOLICITUD_AUTO_EMBARQUE': 'Float64',
    'TIPO_DECLARACION': 'Int64',
    'TIPO_DESPACHO': 'string',
    'COD_LUGAR_SALIDA_NUM': 'Int64',
    'COD_LUG_SALIDA_ALF': 'string',
    'COD_REGION_PROCEDENCIA': 'Int64',
    'REGION_PROCEDENCIA': 'string',
    'NUM__DECLA_EXPORTACION_ANT': 'Int64',
    'NUM_DECLARACION_PRECEDENTE': 'Int64',
    'COD_MODALIDAD_PRECEDENTE': 'string',
    'COD_MONEDA_TRANSACCION': 'string',
    'COD_MODO_TRANSPORTE': 'Int64',
    'MODO_TRANSPORTE': 'string',
    'BANDERA': 'Int64',
    'COD_NACIONALIDAD_BANDERA': 'string',
    'NACIONALIDAD_BANDERA': 'string',
    'COD_REGIMEN_CAN': 'Int64',
    'COD_MODALIDAD_EXPORTACION': 'Int64',
    'MODALIDAD_EXPORTACION': 'string',
    'FORMA_PAGO': 'Int64',
    'COD_TIPO_EMBARQUE': 'Int64',
    'TIPO_DE_EMBARQUE': 'string',
    'COD_TIPO_DATOS': 'Int64',
    'TIPO_DE_DATOS': 'string',
    'TIPO_CERTIFICADO_ORIGEN': 'Int64',
    'SISTEMAS_ESPECIALES': 'string',
    'COD_EXPORTACION_TRANSITO': 'string',
    'EXPORTACION_EN_TRANSITO': 'string',
    'SUBPARTIDA': 'Int64',
    'COD_REGION_ORIGEN': 'Int64',
    'REGION_DE_ORIGEN': 'string',
    'COD_UNIDAD_FISICA_NUM': 'Int64',
    'COD_UNIDAD_FISICA_ALF': 'string',
    'UNIDAD_FISICA': 'string',
    'CANTIDAD_UNIDADES_FISICAS': 'Float64',
    'PESO_BRUTO_KGS': 'Float64',
    'PESO_NETO_KGS': 'Float64',
    'VALOR_FOB_USD': 'Float64',
    'VALOR_FOB_PESOS': 'Float64',
    'VLR_SERIE_AGREGADO_NAL_USD': 'Float64',
    'VALOR_SERIE_FLETES_USD': 'Float64',
    'VALOR_SERIE_SEGUROS_USD': 'Float64',
    'VLR_SERIE_OTROS_GASTOS_USD': 'Float64',
    'COD_ADUANA_SALIDA': 'Int64',
    'ADUANA_SALIDA': 'string',
    'NUMERO_FORMULARIO': 'Int64',
    'RAZON_SOCIAL_EXPORTADOR': 'string',
    'DIREC_EXPORTADOR': 'string',
    'NIT_DECLARANTE': 'Float64',
    'RAZON_SOCIAL_DECLARANTE': 'string',
    'RAZON_SOCIAL_DESTINATARIO': 'string',
    'DOMICILIO_DESTINATARIO': 'string'
})

# %%
# Ver na por columna
df.isna().sum().sort_values(ascending=False)
# Out:
# COD_MODALIDAD_PRECEDENTE         93483
# NIT_EXPORTADOR                     498
# DIREC_EXPORTADOR                   498
# NIT_DECLARANTE                     146
# CIUDAD_DESTINATARIO                 42
# NUM_SOLICITUD_AUTO_EMBARQUE         42
# DOMICILIO_DESTINATARIO              10
# FECHA_PROCESO                        0
# TIPO_USUARIO                         0
# TIPO_IDENT                           0
# ADUANA_DESPACHO                      0
# COD_ADUANA_DESPACHO                  0
# NUMERO_SERIE                         0
# OFICINA                              0
# COD_PAIS_DESTINO_NUM                 0
# COD_DPTO_EXPORTADOR                  0
# PAIS_DESTINO_FINAL                   0
# TIPO_DECLARACION                     0
# TIPO_DESPACHO                        0
# COD_LUGAR_SALIDA_NUM                 0
# COD_LUG_SALIDA_ALF                   0
# COD_PAIS_DESTINO_ALF                 0
# COD_PAIS_DESTINO                     0
# COD_USUARIO                          0
# NUM__DECLA_EXPORTACION_ANT           0
# FECH_DECLA_EXPORTACION_ANT           0
# NUM_DECLARACION_PRECEDENTE           0
# FECH_DECLA_PRECEDENTE                0
# COD_MONEDA_TRANSACCION               0
# COD_MODO_TRANSPORTE                  0
# MODO_TRANSPORTE                      0
# BANDERA                              0
# COD_NACIONALIDAD_BANDERA             0
# NACIONALIDAD_BANDERA                 0
# COD_REGIMEN_CAN                      0
# COD_MODALIDAD_EXPORTACION            0
# MODALIDAD_EXPORTACION                0
# COD_REGION_PROCEDENCIA               0
# REGION_PROCEDENCIA                   0
# CLASE_EXPORTADOR                     0
# TIPO_DE_EMBARQUE                     0
# COD_TIPO_EMBARQUE                    0
# FORMA_PAGO                           0
# COD_TIPO_DATOS                       0
# COD_EXPORTACION_TRANSITO             0
# TIPO_DE_DATOS                        0
# TIPO_CERTIFICADO_ORIGEN              0
# SISTEMAS_ESPECIALES                  0
# REGION_DE_ORIGEN                     0
# COD_UNIDAD_FISICA_NUM                0
# COD_UNIDAD_FISICA_ALF                0
# UNIDAD_FISICA                        0
# CANTIDAD_UNIDADES_FISICAS            0
# EXPORTACION_EN_TRANSITO              0
# SUBPARTIDA                           0
# COD_REGION_ORIGEN                    0
# VALOR_FOB_USD                        0
# PESO_NETO_KGS                        0
# PESO_BRUTO_KGS                       0
# VALOR_FOB_PESOS                      0
# VLR_SERIE_OTROS_GASTOS_USD           0
# VLR_SERIE_AGREGADO_NAL_USD           0
# VALOR_SERIE_FLETES_USD               0
# VALOR_SERIE_SEGUROS_USD              0
# FECHA_SOLICITUD_AUTO_EMBARQUE        0
# ADUANA_SALIDA                        0
# COD_ADUANA_SALIDA                    0
# NUMERO_FORMULARIO                    0
# RAZON_SOCIAL_EXPORTADOR              0
# FECHA_DECLARACION_EXPORTACION        0
# RAZON_SOCIAL_DECLARANTE              0
# RAZON_SOCIAL_DESTINATARIO            0
# dtype: int64

# %% [markdown]
# ### ❓ ¿Por qué hay valores nulos en algunas variables?
#
# Según el **Fallo del Tribunal Administrativo de Cundinamarca** del **19 de septiembre de 2022**, expediente **No. 25000-23-41-000-2022-00994-00**, aclarado mediante auto del **25 de octubre de 2022**, las bases estadísticas **no incluyen variables que contengan datos personales de identificación y ubicación de personas naturales**.
#
# Por esta razón, algunas variables pueden contener valores nulos. Estas son:
#
# - 🆔 `NIT_EXPORTADOR`
# - 📍 `DIREC_EXPORTADOR`
# - 🆔 `NIT_DECLARANTE`
# - 🌆 `CIUDAD_DESTINATARIO`
# - 🏠 `DOMICILIO_DESTINATARIO`
# - 📄 `NUM_SOLICITUD_AUTO_EMBARQUE`
#
# > ℹ️ **Nota:** Esta omisión garantiza la protección de datos personales conforme a la normativa vigente en Colombia.

# %% [markdown]
# ### 📦 ¿Por qué hay valores nulos en `COD_MODALIDAD_PRECEDENTE`?
#
# La columna `COD_MODALIDAD_PRECEDENTE` presenta una alta proporción de valores nulos porque la mayoría de las exportaciones son **regulares, directas y sin operaciones anteriores asociadas**.
#
# A continuación, se muestran ejemplos de cuándo **sí** y **no** aplica una modalidad precedente:
#
# | 💼 **Situación**                                                               | 📋 **¿Hay modalidad precedente?** |
# |-------------------------------------------------------------------------------|-----------------------------------|
# | Exportación regular de bananos                                               | ❌ No                              |
# | Bananos exportados, devueltos, y ahora reexportados                          | ✅ Sí                              |
# | Exportación temporal para procesamiento y luego exportación definitiva       | ✅ Sí                              |
# | Exportación definitiva directa sin operaciones previas                       | ❌ No                              |
#
# > 📝 **Conclusión:** La `modalidad precedente` se registra **solo cuando existe un historial previo de exportación** relacionado con la misma mercancía.
